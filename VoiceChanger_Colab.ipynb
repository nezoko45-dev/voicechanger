# %% [markdown]
# # 🎙️ VoiceChanger — OpenVoice V2 on Google Colab
#
# This notebook clones the GitHub repo, installs the OpenVoice V2 dependencies, checks for a GPU, and launches the Gradio voice changer with a temporary public link.

# %%
# Check the Colab runtime. For best performance, select Runtime → Change runtime type → GPU.
import torch
print('PyTorch:', torch.__version__)
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))
else:
    print('⚠️ No GPU detected. The app can still start, but OpenVoice will be much slower.')

# %%
# Get the latest repo version and install its dependencies.
# !rm -rf /content/voicechanger
# !git clone --depth 1 https://github.com/nezoko45-dev/voicechanger.git /content/voicechanger
# %cd /content/voicechanger
# !pip install -q -r requirements.txt
print('✅ VoiceChanger dependencies installed.')

# %%
# Launch VoiceChanger. Gradio will print a public temporary URL.
# !python app.py
